# %%
import pandas as pd 
import numpy as np 
import BeautifulSoup as bs 
import requests

# %%
url1 = "https://www.broadwayleague.com/research/grosses-broadway-nyc/"

# %%
r1 = requests.get(url1)
r1.status_code
